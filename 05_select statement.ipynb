# %%
df = spark.read.format("parquet")\
    .options(header = True, inforschema = True , multiline = True)\
    .load("/Volumes/data_qa/citi/raw_file/orders.parquet")

# %%
display(df.select('*'))

# %%
display(df.select("order_id","order_date","payment_method","price"))

# %%
display( df.select(df.country,df.payment_method,df.price))

# %%
from pyspark.sql.functions import *
display(df.select(col("country"),col("payment_method"),col("price")))
