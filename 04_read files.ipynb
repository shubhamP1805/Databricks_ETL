# %%
df = spark.read.csv('/Volumes/data_qa/citi/raw_file/orders.csv')

# %%
df.show()

# %%
display(df)

# %% [markdown]
# 1 st way to read the file

# %%
df = spark.read.csv('/Volumes/data_qa/citi/raw_file/orders.csv',header=True,inferSchema=True)
display(df)

# %%
df.printSchema()

# %% [markdown]
# 2 nd and better way to read the data

# %%
df = spark.read.format('csv')\
.options(header=True,inferschema =True)\
.load("/Volumes/data_qa/citi/raw_file/orders.csv")

display(df)

# %%
df = spark.read.format('json')\
    .options(hearder = True, infershema = True,multiline = True)\
    .load("/Volumes/data_qa/default/etl_file/orders file/orders.json")

display(df)

# %%
df = spark.read.format("parquet")\
    .options(header = True, inforschema = True , multiline = True)\
    .load("/Volumes/data_qa/citi/raw_file/orders.parquet")

display(df)
