# %%
data = [
  (1,'Alice',23),
  (2,'Bob',34),
  (3,'Charlie',29),
  (1,'Alice',23),
  (2,'Bob',34),
  (6,'Alice',23)
]
columns = ["id","name","age"]

df = spark.createDataFrame(data,columns)
display(df)

# %%
display(df.distinct())

# %%
display(df.dropDuplicates())

# %%
display(df.dropDuplicates(["name", "age"]))
